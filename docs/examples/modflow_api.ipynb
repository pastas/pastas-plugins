# %% [markdown]
# # Test MODFLOW API

# %%
from pathlib import Path

import flopy
import pastas as ps
from pastas.timer import SolveTimer

from pastas_plugins import modflow as ppmf

bindir = Path("bin")
if not (bindir / "mf6").exists():
    bindir.mkdir(parents=True, exist_ok=True)
    flopy.utils.get_modflow(bindir, repo="modflow6-nightly-build")

dll = bindir / "libmf6.so"

ps.set_use_cache(True)
ps.show_versions()
# Out:
# Pastas     : 2.0.0
# Python     : 3.13.11
# Numpy      : 2.4.4
# Pandas     : 2.3.3
# Scipy      : 1.17.1
# Matplotlib : 3.10.9
# Numba      : 0.65.1

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Load Data

# %%
ds = ps.load_dataset("collenteur_2019")
head = ds["head"].squeeze().dropna()
prec = ds["rain"].squeeze().dropna().resample("D").asfreq().fillna(0.0)
evap = ds["evap"].squeeze().dropna()

prec = prec.loc["2002-11-01":]
evap = evap.loc["2002-11-01":]

# %% [markdown]
# ## MODFLOW API

# %%
ml1 = ps.Model(head, name="mftest")
mfml = ppmf.ModflowModelApi(
    model=ml1,
    dll=dll,
    sim_ws=Path("mftest"),
    silent=False,
)
rch = ppmf.ModflowRch(prec, evap)
ghb = ppmf.ModflowGhb()
mfml.add_modflow_package([rch, ghb])
ml1.add_stressmodel(mfml)
# Out:
# writing simulation...
#   writing simulation name file...
#   writing simulation tdis package...
#   writing solution package ims_-1...
#   writing model mfapi...
#     writing model name file...
#     writing package npf...

# %%
ml1.parameters
# Out:
#               initial      pmin      pmax   vary   name package     dist  \
# DIS_H        0.000000   0.00000  10.00000  False  mfapi     DIS  uniform
# STO_S        0.100000   0.00100   0.50000   True  mfapi     STO  uniform
# RCH_f       -1.000000  -2.00000   0.00000   True  mfapi     RCH  uniform
# constant_d -11.740288 -15.67716  -4.24284   True  mfapi     GHB  uniform
# GHB_C        0.001000   0.00001   0.10000   True  mfapi     GHB  uniform
#
#             stderr  optimal
# DIS_H          NaN      NaN
# STO_S          NaN      NaN
# RCH_f          NaN      NaN
# constant_d     NaN      NaN
# GHB_C          NaN      NaN

# %%
ml1.get_parameters("mfapi")
# Out:
# Model is not optimized yet, initial parameters are used.
# array([ 0.00000000e+00,  1.00000000e-01, -1.00000000e+00, -1.17402885e+01,
#         1.00000000e-03])

# %%
p = tuple(ml1.parameters.initial.values)

# %%
# %%time
sim = ml1.simulate(p)
sim.plot(figsize=(10, 3));

# %%
with SolveTimer() as t:
    ml1.solve(diff_step=1e-4, callback=t.timer)
# Out:
# Optimization progress: 0it [00:00, ?it/s]
# Fit report mftest                   Fit Statistics
# ==================================================
# nfev     25                     EVP          86.49
# nobs     5737                   R2            0.86
# noise    False                  RMSE          0.43
# tmin     2003-01-01 00:00:00    AICc      -9604.32
# tmax     2018-12-25 00:00:00    BIC       -9577.71
# freq     D                      Obj         537.03
# freq_obs None                   ___
# warmup   3650 days 00:00:00     Interp.         No
#
# Parameters (4 optimized)
# ==================================================
#               optimal    initial   vary
# DIS_H        0.000000   0.000000  False
# STO_S        0.306063   0.100000   True
# RCH_f       -0.834215  -1.000000   True
# constant_d -14.206378 -11.740288   True
# GHB_C        0.003043   0.001000   True
#
# Warnings! (1)
# ==================================================
# Parameter 'DIS_H' on lower bound: 0.00e+00

# %% [markdown]
# ## Classic MF6
#
# Solve with classic MF6 implementation.

# %%
ml2 = ps.Model(head, name="mftest")
mfml2 = ppmf.ModflowModel(
    model=ml2,
    exe_name=bindir / "mf6",
    sim_ws=Path("mftest"),
    silent=True,
)
rch = ppmf.ModflowRch(prec, evap)
ghb = ppmf.ModflowGhb()
mfml2.add_modflow_package([rch, ghb])
ml2.add_stressmodel(mfml2)

# %%
p = tuple(ml2.parameters.initial.values)

# %%
# %%time
sim2 = ml2.simulate(p)
sim2.plot(figsize=(10, 3));

# %%
with SolveTimer() as t:
    ml2.solve(diff_step=1e-4, callback=t.timer)
# Out:
# Optimization progress: 0it [00:00, ?it/s]
# Fit report mftest                   Fit Statistics
# ==================================================
# nfev     27                     EVP          86.49
# nobs     5737                   R2            0.86
# noise    False                  RMSE          0.43
# tmin     2003-01-01 00:00:00    AICc      -9604.32
# tmax     2018-12-25 00:00:00    BIC       -9577.71
# freq     D                      Obj         537.03
# freq_obs None                   ___
# warmup   3650 days 00:00:00     Interp.         No
#
# Parameters (4 optimized)
# ==================================================
#               optimal    initial   vary
# DIS_H        0.000000   0.000000  False
# STO_S        0.305953   0.100000   True
# RCH_f       -0.833474  -1.000000   True
# constant_d -14.208003 -11.740288   True
# GHB_C        0.003043   0.001000   True
#
# Warnings! (1)
# ==================================================
# Parameter 'DIS_H' on lower bound: 0.00e+00

# %% [markdown]
# ## Pastas

# %%
ml3 = ps.Model(head, name="pastas")
rm = ps.RechargeModel(prec, evap, rfunc=ps.Exponential(), name="rch")
ml3.add_stressmodel(rm)
ml3.solve()
# Out:
# Fit report pastas                   Fit Statistics
# ==================================================
# nfev     19                     EVP          86.49
# nobs     5737                   R2            0.86
# noise    False                  RMSE          0.43
# tmin     2003-01-01 00:00:00    AICc      -9606.91
# tmax     2018-12-25 00:00:00    BIC       -9580.30
# freq     D                      Obj         536.78
# freq_obs None                   ___
# warmup   3650 days 00:00:00     Interp.         No
#
# Parameters (4 optimized)
# ==================================================
#                optimal    initial  vary
# rch_A       328.491207  29.263690  True
# rch_a       101.045697  10.000000  True
# rch_f        -0.834875  -1.000000  True
# constant_d  -14.202052 -11.740288  True

# %%
ax = ml3.plot(figsize=(8, 3))
sim1 = ml1.simulate()
ax.plot(sim1.index, sim1, label=f"API ({ml1.stats.rsq():.2%})")
sim2 = ml2.simulate()
ax.plot(sim2.index, sim2, label=f"MF6 ({ml2.stats.rsq():.2%})")
ax.legend(loc=(0, 1), frameon=False, ncol=4);
# Out:
# /tmp/ipykernel_2855924/1031973391.py:3: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   ax.plot(sim1.index, sim1, label=f"API ({ml1.stats.rsq():.2%})")

# %% [markdown]
# Compare parameters of all three models

# %%
cp = ps.CompareModels([ml1, ml2, ml3], names=["api", "mf6", "pastas"])
cp.plot_table_params();
